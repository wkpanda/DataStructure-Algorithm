# %%
import time
import threading

#号码
class Node():
    def __init__(self,x):
        self.data = x
        self.next=None

# %%
#队列结构
class LinkedQUeue():
    def __init__(self):
        self._head = None
        self._tail = None
    def isEmpty(self):
        return self._head==self._tail:
    
    def enqueue(self,val):
        newNode=Node(val)
        if self._tail==None:
            self._head=newNode
        else:
            self._tail.next=newNode
        self._tail = newNode
       # 出队
    def dequeue(self):
        # 如果队列为空
        if self._head == self._tail:
            return None
        else:
            node = self._head
            self._head = self._head.next
            return node.data

    def __repr__(self):
        # 队列为空
        if self._head == self._tail:
            return '空'
        else:
            result = []
            cur = self._head
            while cur != None:
                result.append(cur.data)
                cur = cur.next
            return '->'.join(str(x) for x in result)
# Out:
#   File "<ipython-input-4-f79b50e5a1b2>", line 7
#     return self._head==self._tail:
#                                  ^
# SyntaxError: invalid syntax

# %%
#队列结构
class LinkedQUeue():
    def __init__(self):
        self._head = None
        self._tail = None
    def isEmpty(self):
        return self._head==self._tail
    
    def enqueue(self,val):
        newNode=Node(val)
        if self._tail==None:
            self._head=newNode
        else:
            self._tail.next=newNode
        self._tail = newNode
       # 出队
    def dequeue(self):
        # 如果队列为空
        if self._head == self._tail:
            return None
        else:
            node = self._head
            self._head = self._head.next
            return node.data

    def __repr__(self):
        # 队列为空
        if self._head == self._tail:
            return '空'
        else:
            result = []
            cur = self._head
            while cur != None:
                result.append(cur.data)
                cur = cur.next
            return '->'.join(str(x) for x in result)

# %%
# 银行排队系统，存储排队号码
class LinkBankQueue(LinkedQueue):
    def __init__(self):
        LinkedQueue.__init__(self)
        self.callNumber = 0

    def getCallNumber(self):
        if self.is_empty() and self.callNumber == 0:
            self.callNumber = 1
        else:
            self.callNumber += 1
        return self.callNumber

    def getLength(self):
        if self.is_empty():
            return 0
        else:
            cur = self._head
            len = 1
            while cur != self._tail:
                cur = cur.next
                len += 1
            return len
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6805d739aaaf> in <module>
#       1 # 银行排队系统，存储排队号码
# ----> 2 class LinkBankQueue(LinkedQueue):
#       3     def __init__(self):
#       4         LinkedQueue.__init__(self)
#       5         self.callNumber = 0
#
# NameError: name 'LinkedQueue' is not defined

# %%
#队列结构
class LinkedQueue():
    def __init__(self):
        self._head = None
        self._tail = None
    def isEmpty(self):
        return self._head==self._tail
    
    def enqueue(self,val):
        newNode=Node(val)
        if self._tail==None:
            self._head=newNode
        else:
            self._tail.next=newNode
        self._tail = newNode
       # 出队
    def dequeue(self):
        # 如果队列为空
        if self._head == self._tail:
            return None
        else:
            node = self._head
            self._head = self._head.next
            return node.data

    def __repr__(self):
        # 队列为空
        if self._head == self._tail:
            return '空'
        else:
            result = []
            cur = self._head
            while cur != None:
                result.append(cur.data)
                cur = cur.next
            return '->'.join(str(x) for x in result)

# %%
# 银行排队系统，存储排队号码
class LinkBankQueue(LinkedQueue):
    def __init__(self):
        LinkedQueue.__init__(self)
        self.callNumber = 0

    def getCallNumber(self):
        if self.is_empty() and self.callNumber == 0:
            self.callNumber = 1
        else:
            self.callNumber += 1
        return self.callNumber

    def getLength(self):
        if self.is_empty():
            return 0
        else:
            cur = self._head
            len = 1
            while cur != self._tail:
                cur = cur.next
                len += 1
            return len

# %%
# 服务器
class ServiceWindow(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.bankQueue = None
        self.lock = threading.Lock()

    def service(self):
        self.lock.acquire()
        while True:
            time.sleep(20)
            try:
                if not self.bankQueue.is_empty():
                    print('请 %d 号到 %s 号窗口' % (self.bankQueue._head.data, threading.current_thread().name))
                    self.bankQueue.dequeue()
                    # time.sleep(10)
                else:
                    print('队列为空哦')
            finally:
                self.lock.release()

# %%
客户端
if __name__ == '__main__':
    bankQueue = LinkBankQueue()
    windowcount = 2
    serviceWindows = [None] * windowcount
    threadList = [None] * windowcount
    for i in range(windowcount):
        serviceWindows[i] = ServiceWindow()
        serviceWindows[i].bankQueue = bankQueue
        threadList[i] = threading.Thread(name=(i + 1), target=serviceWindows[i].service, args=())
        threadList[i].start()
    while True:
        input('请点击触摸屏获取号码：')
        callNumber = bankQueue.getCallNumber()
        if bankQueue != None:
            print('您的号码是：%d，您前面有 %d 位' % (callNumber, bankQueue.getLength()))
            bankQueue.enqueue(callNumber)
        else:
            print('您的号码是：%d，您前面有 0 位' % (callNumber))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e8907ad7ca63> in <module>
# ----> 1 客户端
#       2 if __name__ == '__main__':
#       3     bankQueue = LinkBankQueue()
#       4     windowcount = 2
#       5     serviceWindows = [None] * windowcount
#
# NameError: name '客户端' is not defined

# %%
#客户端
if __name__ == '__main__':
    bankQueue = LinkBankQueue()
    windowcount = 2
    serviceWindows = [None] * windowcount
    threadList = [None] * windowcount
    for i in range(windowcount):
        serviceWindows[i] = ServiceWindow()
        serviceWindows[i].bankQueue = bankQueue
        threadList[i] = threading.Thread(name=(i + 1), target=serviceWindows[i].service, args=())
        threadList[i].start()
    while True:
        input('请点击触摸屏获取号码：')
        callNumber = bankQueue.getCallNumber()
        if bankQueue != None:
            print('您的号码是：%d，您前面有 %d 位' % (callNumber, bankQueue.getLength()))
            bankQueue.enqueue(callNumber)
        else:
            print('您的号码是：%d，您前面有 0 位' % (callNumber))
# Out:
# 请点击触摸屏获取号码：
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-0d44c2cb0c63> in <module>
#      12     while True:
#      13         input('请点击触摸屏获取号码：')
# ---> 14         callNumber = bankQueue.getCallNumber()
#      15         if bankQueue != None:
#      16             print('您的号码是：%d，您前面有 %d 位' % (callNumber, bankQueue.getLength()))
#
# <ipython-input-8-6805d739aaaf> in getCallNumber(self)
#       6
#       7     def getCallNumber(self):
# ----> 8         if self.is_empty() and self.callNumber == 0:
#       9             self.callNumber = 1
#      10         else:
#
# AttributeError: 'LinkBankQueue' object has no attribute 'is_empty'
# Exception in thread 1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-8d0836798387>", line 13, in service
#     if not self.bankQueue.is_empty():
# AttributeError: 'LinkBankQueue' object has no attribute 'is_empty'
# Exception in thread 2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-9-8d0836798387>", line 13, in service
#     if not self.bankQueue.is_empty():
# AttributeError: 'LinkBankQueue' object has no attribute 'is_empty'

# %%
import time
import threading

#号码
class Node():
    def __init__(self,x):
        self.data = x
        self.next=None
# 队列结构
class LinkedQueue():
    def __init__(self):
        self._head = None
        self._tail = None

    def is_empty(self):
        if self._head == self._tail:
            return True
        else:
            return False

    # 入队
    def enqueue(self, val):
        newNode = Node(val)
        # 如果链表队列为空
        if self._tail == None:
            self._head = newNode
        else:
            self._tail.next = newNode
        self._tail = newNode

    # 出队
    def dequeue(self):
        # 如果队列为空
        if self._head == self._tail:
            return None
        else:
            node = self._head
            self._head = self._head.next
            return node.data

    def __repr__(self):
        # 队列为空
        if self._head == self._tail:
            return '空'
        else:
            result = []
            cur = self._head
            while cur != None:
                result.append(cur.data)
                cur = cur.next
            return '->'.join(str(x) for x in result)
# 银行排队系统，存储排队号码
class LinkBankQueue(LinkedQueue):
    def __init__(self):
        LinkedQueue.__init__(self)
        self.callNumber = 0

    def getCallNumber(self):
        if self.is_empty() and self.callNumber == 0:
            self.callNumber = 1
        else:
            self.callNumber += 1
        return self.callNumber

    def getLength(self):
        if self.is_empty():
            return 0
        else:
            cur = self._head
            len = 1
            while cur != self._tail:
                cur = cur.next
                len += 1
            return len

# 服务器
class ServiceWindow(threading.Thread):
    def __init__(self):
        threading.Thread.__init__(self)
        self.bankQueue = None
        self.lock = threading.Lock()

    def service(self):
        self.lock.acquire()
        while True:
            time.sleep(20)
            try:
                if not self.bankQueue.is_empty():
                    print('请 %d 号到 %s 号窗口' % (self.bankQueue._head.data, threading.current_thread().name))
                    self.bankQueue.dequeue()
                    # time.sleep(10)
                else:
                    print('队列为空哦')
            finally:
                self.lock.release()
#客户端
if __name__ == '__main__':
    bankQueue = LinkBankQueue()
    windowcount = 2
    serviceWindows = [None] * windowcount
    threadList = [None] * windowcount
    for i in range(windowcount):
        serviceWindows[i] = ServiceWindow()
        serviceWindows[i].bankQueue = bankQueue
        threadList[i] = threading.Thread(name=(i + 1), target=serviceWindows[i].service, args=())
        threadList[i].start()
    while True:
        input('请点击触摸屏获取号码：')
        callNumber = bankQueue.getCallNumber()
        if bankQueue != None:
            print('您的号码是：%d，您前面有 %d 位' % (callNumber, bankQueue.getLength()))
            bankQueue.enqueue(callNumber)
        else:
            print('您的号码是：%d，您前面有 0 位' % (callNumber))
# Out:
# 请点击触摸屏获取号码：
# 您的号码是：1，您前面有 0 位
# 请点击触摸屏获取号码：
# 您的号码是：2，您前面有 0 位
# 请点击触摸屏获取号码：
# 您的号码是：3，您前面有 2 位
# 请点击触摸屏获取号码：
# 您的号码是：4，您前面有 3 位
# 请点击触摸屏获取号码：
# 您的号码是：5，您前面有 4 位
# 请点击触摸屏获取号码：
# 您的号码是：6，您前面有 5 位
# 请点击触摸屏获取号码：
# 您的号码是：7，您前面有 6 位
# 请点击触摸屏获取号码：
# 您的号码是：8，您前面有 7 位
# 请点击触摸屏获取号码：
# 您的号码是：9，您前面有 8 位
# 请点击触摸屏获取号码：
# 您的号码是：10，您前面有 9 位
# 请点击触摸屏获取号码：
# 您的号码是：11，您前面有 10 位
# 请点击触摸屏获取号码：
# 您的号码是：12，您前面有 11 位
# 请点击触摸屏获取号码：
# 请 1 号到 2 号窗口
# 请 2 号到 1 号窗口
# 您的号码是：13，您前面有 10 位
# 请点击触摸屏获取号码：
# 您的号码是：14，您前面有 11 位
# 请点击触摸屏获取号码：
# 您的号码是：15，您前面有 12 位
# 请点击触摸屏获取号码：
# 您的号码是：16，您前面有 13 位
# 请点击触摸屏获取号码：
# 您的号码是：17，您前面有 14 位
# 请点击触摸屏获取号码：
# 您的号码是：18，您前面有 15 位
# 请点击触摸屏获取号码：
# 您的号码是：19，您前面有 16 位
# 请点击触摸屏获取号码：
# 您的号码是：20，您前面有 17 位
# 请点击触摸屏获取号码：
# 您的号码是：21，您前面有 18 位
# 请点击触摸屏获取号码：
# 您的号码是：22，您前面有 19 位
# 请点击触摸屏获取号码：
# 您的号码是：23，您前面有 20 位
# 请点击触摸屏获取号码：
# 您的号码是：24，您前面有 21 位
# 请点击触摸屏获取号码：
# 您的号码是：25，您前面有 22 位
# 请点击触摸屏获取号码：
# 您的号码是：26，您前面有 23 位
# 请点击触摸屏获取号码：
# 您的号码是：27，您前面有 24 位
# 请点击触摸屏获取号码：
# 您的号码是：28，您前面有 25 位
# 请点击触摸屏获取号码：
# 您的号码是：29，您前面有 26 位
# 请点击触摸屏获取号码：
# 您的号码是：30，您前面有 27 位
# 请点击触摸屏获取号码：
# 您的号码是：31，您前面有 28 位
# 请点击触摸屏获取号码：
# 您的号码是：32，您前面有 29 位
# 请点击触摸屏获取号码：
# 您的号码是：33，您前面有 30 位
# 请点击触摸屏获取号码：
# 您的号码是：34，您前面有 31 位
# 请点击触摸屏获取号码：
# 您的号码是：35，您前面有 32 位
# 请点击触摸屏获取号码：
# 您的号码是：36，您前面有 33 位
# 请点击触摸屏获取号码：
# 您的号码是：37，您前面有 34 位
# 请点击触摸屏获取号码：
# 您的号码是：38，您前面有 35 位
# 请点击触摸屏获取号码：
# 您的号码是：39，您前面有 36 位
# 请点击触摸屏获取号码：
# 您的号码是：40，您前面有 37 位
# 请点击触摸屏获取号码：
# 您的号码是：41，您前面有 38 位
# 请 3 号到 2 号窗口
# 请 4 号到 1 号窗口
# Exception in thread 2:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-12-b239472997e7>", line 95, in service
#     self.lock.release()
# RuntimeError: release unlocked lock
#
# Exception in thread 1:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-12-b239472997e7>", line 95, in service
#     self.lock.release()
# RuntimeError: release unlocked lock
